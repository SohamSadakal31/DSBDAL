# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
df['embark_town'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %%
corr = df[['age','fare','pclass','sibsp','parch']].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify
sizes = df['class'].value_counts()
plt.figure(figsize=(6,6))
squarify.plot(
    sizes=sizes.values,
    label=sizes.index,
    alpha=0.8
)
plt.title("Passenger Class Distribution")
plt.axis("off")
plt.show()

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.19.3 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp313-cp313-macosx_11_0_arm64.whl (168 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
text = " data visualization charts scatter plotted map data structures box plot heatmap pandas python seaborn matplotlib analytics "
wc = WordCloud(background_color="white").generate(text)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
table = pd.crosstab(df['sex'], df['survived'])
table.plot(kind='bar', stacked=True)
plt.title("Survival Count by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
pip install waterfallcharts
# Out:
# Collecting waterfallcharts
#   Downloading waterfallcharts-3.8.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: waterfallcharts
#   DEPRECATION: Building 'waterfallcharts' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'waterfallcharts'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for waterfallcharts (setup.py) ... one
#   Created wheel for waterfallcharts: filename=waterfallcharts-3.8-py3-none-any.whl size=3389 sha256=ddf2fa56330242b6c467733d9ac35f9ad033aa1097e11d73bab03652dbe1d088
#   Stored in directory: /Users/kaushalpokarne/Library/Caches/pip/wheels/c1/e8/5c/552d3a69be59b56d1736bd65d72d6c54a18cbf7a4d8535c460
# Successfully built waterfallcharts
# Installing collected packages: waterfallcharts
# Successfully installed waterfallcharts-3.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import waterfall_chart
labels = ["Start","Loss","Gain","Final"]
values = [100,-30,50,-10]
waterfall_chart.plot(labels, values)
plt.title("Sample Waterfall Chart")
plt.show()
# Out:
# /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages/waterfall_chart.py:84: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '#29EA38' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   trans.loc[trans['positive'] == 1, 'color'] = green_color
# /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages/waterfall_chart.py:141: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = y_height[loop] + row['amount']
# /Users/kaushalpokarne/Documents/Anaconda/anaconda3/lib/python3.13/site-packages/waterfall_chart.py:139: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = y_height[loop]
